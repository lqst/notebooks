# %%
from graphdatascience import GraphDataScience
import graph_tool.all as gt
import matplotlib.pyplot as plt

# %%
DB_ULR = "neo4j://localhost:7687"
DB_USER = "neo4j"
DB_PASS = "test1234"
DB_NAME = "movies"
gds = GraphDataScience(DB_ULR, auth=(DB_USER, DB_PASS))
gds.set_database(DB_NAME)
gds.version()
# Out:
# '2.2.7'

# %%
plt.switch_backend("cairo")
g = gt.collection.data["polbooks"]

gt.graph_draw(g, vertex_size=1.5)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x107634b20, at 0x17fe256d0>

# %%
import ipyreact
class ConfettiWidget(ipyreact.ReactWidget):
  _esm = """
    import confetti from "canvas-confetti";
    import * as React from "react";
    export default function({value, set_value, debug}) {
        return (
        <>
          <h1>Happy New Year 2024 🎉 from Datalayer</h1>
          <button onClick={() => confetti() && set_value(value + 1)}>
            CLICK here for some CONFETTIS
          </button>
          <h2>You have {value || 0} wishe{ (value > 1) && 's' } so far...</h2>
          <quote>Powered by 🪐 Jupyter UI</quote>
        </>
      )
    };"""
ConfettiWidget()
# Out:
# ConfettiWidget()

# %%
class Test(ipyreact.ReactWidget):
    _esm = """
    import * as React from "react";
    export default function({value, set_value, debug}) {
        return (
          <h1>Happy New Year 2024 🎉 from Datalayer</h1>
      )
    };
"""
Test()
# Out:
# Test()
