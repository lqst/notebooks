# %% [markdown]
# # Knowledge Graph Agent with LlamaParse
#
# <a href="https://colab.research.google.com/github/run-llama/llama_parse/blob/main/examples/knowledge_graphs/kg_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Here we build a knowledge graph agent over the SF 2023 Budget Proposal. We use LlamaIndex abstractions to construct a knowledge graph, and we store the property graph in neo4j. We then build an agent that can interact with the knowledge graph as a tool.

# %% [markdown]
# ## Setup (Installs, Data, Models)

# %%
# !pip install llama-index
# !pip install llama-index-core==0.10.42
# !pip install llama-index-embeddings-openai
# !pip install llama-index-postprocessor-flag-embedding-reranker
# !pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# !pip install llama-index-graph-stores-neo4j
# !pip install llama-parse
# Out:
# Requirement already satisfied: llama-index in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (0.10.44)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.2.7)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.12)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.6)
# Collecting llama-index-core==0.10.44
#   Using cached llama_index_core-0.10.44-py3-none-any.whl (15.4 MB)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.23)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.10)
# Requirement already satisfied: llama-index-readers-llama-parse<0.2.0,>=0.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index) (0.1.22)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.6.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.2.14)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.24.2)
# Requirement already satisfied: httpx in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (0.27.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (2024.3.1)
# Requirement already satisfied: wrapt in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.15.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.0.8)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (0.9.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (0.6.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (6.0.1)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (2.32.3)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (9.4.0)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (0.6.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (0.1.19)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.33.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (3.2.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (8.2.3)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (1.5.3)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (2.0.22)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (4.10.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.44->llama-index) (3.8.6)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.2.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse<0.5.0,>=0.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index) (0.4.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama-index) (1.9.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.3.2.post1)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.44->llama-index) (1.10.13)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.44->llama-index) (3.4)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.44->llama-index) (1.3.0)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.44->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.44->llama-index) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.44->llama-index) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.44->llama-index) (0.14.0)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama-index) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama-index) (2023.10.3)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama-index) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.44->llama-index) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core==0.10.44->llama-index) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.44->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from dataclasses-json->llama-index-core==0.10.44->llama-index) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.44->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.44->llama-index) (2022.7.1)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from anyio->httpx->llama-index-core==0.10.44->llama-index) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.44->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core==0.10.44->llama-index) (1.16.0)
# Installing collected packages: llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.10.42
#     Uninstalling llama-index-core-0.10.42:
#       Successfully uninstalled llama-index-core-0.10.42
# Successfully installed llama-index-core-0.10.44
# Collecting llama-index-core==0.10.42
#   Using cached llama_index_core-0.10.42-py3-none-any.whl (15.4 MB)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (0.9.0)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.33.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (2.0.22)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (3.8.6)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (0.6.1)
# Requirement already satisfied: httpx in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (0.27.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.0.8)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (0.1.19)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (2024.3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (3.8.1)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (0.6.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.2.14)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (8.2.3)
# Requirement already satisfied: wrapt in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.15.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (3.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (4.66.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (9.4.0)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.5.3)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (2.32.3)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (1.24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core==0.10.42) (4.10.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (4.0.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.42) (1.3.1)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.42) (1.10.13)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.42) (2023.7.22)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.42) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.42) (1.0.4)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.42) (3.4)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.42) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.42) (0.14.0)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.42) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.42) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.42) (2023.10.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.42) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core==0.10.42) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.42) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.42) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from dataclasses-json->llama-index-core==0.10.42) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.42) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.42) (2022.7.1)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from anyio->httpx->llama-index-core==0.10.42) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.42) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core==0.10.42) (1.16.0)
# Installing collected packages: llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.10.44
#     Uninstalling llama-index-core-0.10.44:
#       Successfully uninstalled llama-index-core-0.10.44
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index 0.10.44 requires llama-index-core==0.10.44, but you have llama-index-core 0.10.42 which is incompatible.
# Successfully installed llama-index-core-0.10.42
# Requirement already satisfied: llama-index-embeddings-openai in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (0.1.10)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-embeddings-openai) (0.10.42)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.33.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.1)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (9.4.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.3.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.6)
# Requirement already satisfied: httpx in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.27.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.22)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.5.3)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.2.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.1.19)
# Requirement already satisfied: wrapt in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.15.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.10.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.24.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.0.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.4)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.10.13)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.4)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.0)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.4)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.7.22)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.7.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.10.3)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2022.7.1)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: llama-index-postprocessor-flag-embedding-reranker in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (0.1.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.35 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-postprocessor-flag-embedding-reranker) (0.10.42)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2.32.3)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (9.4.0)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.33.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.6.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.24.2)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (0.1.19)
# Requirement already satisfied: wrapt in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.15.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (4.10.0)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (0.6.1)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.5.3)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2024.3.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (6.0.1)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.2.14)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.8.6)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2.0.22)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (4.66.4)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (0.9.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.8.1)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (0.6.0)
# Requirement already satisfied: httpx in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (0.27.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.4.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.10.13)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.0.4)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.3.0)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.7.1)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (0.14.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2023.10.3)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.2.0)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (8.1.7)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2022.7.1)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (1.16.0)
# Collecting git+https://github.com/FlagOpen/FlagEmbedding.git
#   Cloning https://github.com/FlagOpen/FlagEmbedding.git to /private/var/folders/71/lgz4464j18s5g22_s_lm696m0000gn/T/pip-req-build-cgnvimi3
#   Running command git clone --filter=blob:none --quiet https://github.com/FlagOpen/FlagEmbedding.git /private/var/folders/71/lgz4464j18s5g22_s_lm696m0000gn/T/pip-req-build-cgnvimi3
#   Resolved https://github.com/FlagOpen/FlagEmbedding.git to commit c6cb733cd3c551d3e1e97e4bcc2e29dd76cce4a1
#   Preparing metadata (setup.py) ... done
# ...
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (6.0.4)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.10.13)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (3.4)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.0.4)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (2023.7.22)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (3.7.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (0.14.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (2023.10.3)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (2.8.2)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.40->llama-index-graph-stores-neo4j) (1.16.0)
# Requirement already satisfied: llama-parse in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (0.4.4)
# Requirement already satisfied: llama-index-core>=0.10.29 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-parse) (0.10.42)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (3.2.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (6.0.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (3.8.1)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.2.14)
# Requirement already satisfied: wrapt in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.15.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.24.2)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.33.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (3.8.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (4.10.0)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.6.1)
# Requirement already satisfied: httpx in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.27.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (8.2.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.9.0)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.5.3)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (2024.3.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.6.0)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (2.32.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (4.66.4)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.6.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.1.19)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llama-index-core>=0.10.29->llama-parse) (2.0.22)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (4.0.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (2.1.1)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (1.10.13)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (1.0.4)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (2023.7.22)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (1.3.0)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core>=0.10.29->llama-parse) (0.14.0)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (2023.10.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core>=0.10.29->llama-parse) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core>=0.10.29->llama-parse) (1.26.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.10.29->llama-parse) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core>=0.10.29->llama-parse) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from dataclasses-json->llama-index-core>=0.10.29->llama-parse) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2022.7.1)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from anyio->httpx->llama-index-core>=0.10.29->llama-parse) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core>=0.10.29->llama-parse) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core>=0.10.29->llama-parse) (1.16.0)

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
import os

# API access to llama-cloud
# os.environ["LLAMA_CLOUD_API_KEY"] = "llx-"

# %% [markdown]
# #### Setup Model
#
# Here we use gpt-4o and default OpenAI embeddings.

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

llm = OpenAI(model="gpt-4o")
embed_model = OpenAIEmbedding(model="text-embedding-3-small")

Settings.llm = llm
Settings.embed_model = embed_model

# %% [markdown]
# #### Load Data
#
# Here we load the 2023 Budget PDF and parse it with LlamaParse.

# %%
# !mkdir data
# !wget "https://www.dropbox.com/scl/fi/vip161t63s56vd94neqlt/2023-CSF_Proposed_Budget_Book_June_2023_Master_Web.pdf?rlkey=hemoce3w1jsuf6s2bz87g549i&dl=0" -O data/budget_2023.pdf
# Out:
# mkdir: data: File exists
# --2024-06-11 13:57:20--  https://www.dropbox.com/scl/fi/vip161t63s56vd94neqlt/2023-CSF_Proposed_Budget_Book_June_2023_Master_Web.pdf?rlkey=hemoce3w1jsuf6s2bz87g549i&dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.66.18, 2620:100:6022:18::a27d:4212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.66.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com/cd/0/inline/CUoLFcq8Q9pj4Mg2im0f1pcfXHptlqGevyWF4zqMbJPbQ7Ff9056stxNcFypsYjNNvHdDkfrQcY5rttFyy1F3_e5axhUEiGnKQkxrlahn9jLG4ecHk96qywFU7zCWqmfzhk/file# [following]
# --2024-06-11 13:57:21--  https://ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com/cd/0/inline/CUoLFcq8Q9pj4Mg2im0f1pcfXHptlqGevyWF4zqMbJPbQ7Ff9056stxNcFypsYjNNvHdDkfrQcY5rttFyy1F3_e5axhUEiGnKQkxrlahn9jLG4ecHk96qywFU7zCWqmfzhk/file
# Resolving ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com (ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com)... 162.125.66.15, 2620:100:6022:15::a27d:420f
# Connecting to ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com (ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com)|162.125.66.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CUr6wbN1IWzDqnsDVAdLvkn0Xx6LRifeQgc87unEN56XXyvDVgSqbf2Vjn0K1YI5ua2c0ErkY7MMPmv197u_EVsyZz1kUEar5YuE29VM7wI1UkvXOM6bEOSUpi09IdKfNJBag0B-75Kc38V8kWCmuvVX9uCZJfLkBmlx5giZ6-kHzp3PcI98d3NAuatBcLI_-r-6BRSwupQwwokgO6wLicFuEtQhQdJsMaiNIKdrX3JPPkDfS6o1KaPyIqQn7N2aqH4fs8rTdg9qvbl6o7kNJsjur8DShMPw7YKUu47oSqrVpyDRkzOjbuYK7lgK8y3TqvDImlsTJnSyMUh2AnkG9TWkzKSj6-sL8U_Mi9UHC6v8Ew/file [following]
# --2024-06-11 13:57:22--  https://ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com/cd/0/inline2/CUr6wbN1IWzDqnsDVAdLvkn0Xx6LRifeQgc87unEN56XXyvDVgSqbf2Vjn0K1YI5ua2c0ErkY7MMPmv197u_EVsyZz1kUEar5YuE29VM7wI1UkvXOM6bEOSUpi09IdKfNJBag0B-75Kc38V8kWCmuvVX9uCZJfLkBmlx5giZ6-kHzp3PcI98d3NAuatBcLI_-r-6BRSwupQwwokgO6wLicFuEtQhQdJsMaiNIKdrX3JPPkDfS6o1KaPyIqQn7N2aqH4fs8rTdg9qvbl6o7kNJsjur8DShMPw7YKUu47oSqrVpyDRkzOjbuYK7lgK8y3TqvDImlsTJnSyMUh2AnkG9TWkzKSj6-sL8U_Mi9UHC6v8Ew/file
# Reusing existing connection to ucae758d191d99eafcaa8a6d3046.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10550407 (10M) [application/pdf]
# Saving to: ‘data/budget_2023.pdf’
#
# data/budget_2023.pd 100%[===================>]  10,06M  12,5MB/s    in 0,8s
#
# 2024-06-11 13:57:23 (12,5 MB/s) - ‘data/budget_2023.pdf’ saved [10550407/10550407]

# %%
from llama_parse import LlamaParse

docs = LlamaParse(result_type="text").load_data("./data/budget_2023.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 from llama_parse import LlamaParse
# ----> 3 docs = LlamaParse(result_type="text").load_data("./data/budget_2023.pdf")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for LlamaParse
# api_key
#   The API key is required. (type=value_error)

# %%
from copy import deepcopy
from llama_index.core.schema import TextNode, Document
from llama_index.core import VectorStoreIndex


def get_sub_docs(docs):
    """Split docs into pages, by separator."""
    sub_docs = []
    for doc in docs:
        doc_chunks = doc.text.split("\n---\n")
        for doc_chunk in doc_chunks:
            sub_doc = Document(
                text=doc_chunk,
                metadata=deepcopy(doc.metadata),
            )
            sub_docs.append(sub_doc)

    return sub_docs

# %%
# this will split into pages
sub_docs = get_sub_docs(docs)

# %% [markdown]
# #### Initialize Graph Store
#
# Here we use Neo4j but you can also use our other integrations like Nebula (see an [example notebook](https://github.com/run-llama/llama_index/blob/main/docs/docs/examples/property_graph/property_graph_advanced.ipynb)).

# %% [markdown]
# To launch Neo4j locally, first ensure you have docker installed. Then, you can launch the database with the following docker command
#
# ```bash
# docker run \
#     -p 7474:7474 -p 7687:7687 \
#     -v $PWD/data:/data -v $PWD/plugins:/plugins \
#     --name neo4j-apoc \
#     -e NEO4J_apoc_export_file_enabled=true \
#     -e NEO4J_apoc_import_file_enabled=true \
#     -e NEO4J_apoc_import_file_use__neo4j__config=true \
#     -e NEO4JLABS_PLUGINS=\[\"apoc\"\] \
#     neo4j:latest
# ```
#
# From here, you can open the db at [http://localhost:7474/](http://localhost:7474/). On this page, you will be asked to sign in. Use the default username/password of `neo4j` and `neo4j`.
#
# Once you login for the first time, you will be asked to change the password.
#
# After this, you are ready to create your first property graph!

# %%
from llama_index.graph_stores.neo4j import Neo4jPGStore

graph_store = Neo4jPGStore(
    username="neo4j",
    password="test1234",
    url="bolt://localhost:7687",
)
vec_store = None

# %% [markdown]
# ## Construct Knowledge Graph, Get Retrievers
#
# This section shows you how to construct the knowledge graph over the existing documents.
#
# **Note**: we have the default extractors (implicit path, simple llm path) configured. You can also choose to use a pre-defined schema as mentioned in this [notebook](https://github.com/run-llama/llama_index/blob/main/docs/docs/examples/property_graph/property_graph_advanced.ipynb).

# %%
from llama_index.core.indices.property_graph import (
    ImplicitPathExtractor,
    SimpleLLMPathExtractor,
)
from llama_index.core import PropertyGraphIndex
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding

# %%
# !pip show llama-index llama-index-core llama-index-embeddings-openai llama-index-postprocessor-flag-embedding-reranker  llama-index-graph-stores-neo4j llama-parse
# Out:
# Name: llama-index
# Version: 0.10.44
# Summary: Interface between LLMs and your data
# Home-page: https://llamaindex.ai
# Author: Jerry Liu
# Author-email: jerry@llamaindex.ai
# License: MIT
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages
# Requires: llama-index-agent-openai, llama-index-cli, llama-index-core, llama-index-embeddings-openai, llama-index-indices-managed-llama-cloud, llama-index-legacy, llama-index-llms-openai, llama-index-multi-modal-llms-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index-readers-file, llama-index-readers-llama-parse
# Required-by:
# ---
# Name: llama-index-core
# Version: 0.10.42
# Summary: Interface between LLMs and your data
# Home-page: https://llamaindex.ai
# Author: Jerry Liu
# Author-email: jerry@llamaindex.ai
# License: MIT
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages
# Requires: aiohttp, dataclasses-json, deprecated, dirtyjson, fsspec, httpx, llamaindex-py-client, nest-asyncio, networkx, nltk, numpy, openai, pandas, pillow, PyYAML, requests, SQLAlchemy, tenacity, tiktoken, tqdm, typing-extensions, typing-inspect, wrapt
# Required-by: llama-index, llama-index-agent-openai, llama-index-cli, llama-index-embeddings-openai, llama-index-graph-stores-neo4j, llama-index-indices-managed-llama-cloud, llama-index-llms-openai, llama-index-multi-modal-llms-openai, llama-index-postprocessor-flag-embedding-reranker, llama-index-program-openai, llama-index-question-gen-openai, llama-index-readers-file, llama-index-readers-llama-parse, llama-parse
# ---
# Name: llama-index-embeddings-openai
# Version: 0.1.10
# Summary: llama-index embeddings openai integration
# Home-page:
# Author: Your Name
# Author-email: you@example.com
# License: MIT
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages
# Requires: llama-index-core
# Required-by: llama-index, llama-index-cli
# ---
# Name: llama-index-postprocessor-flag-embedding-reranker
# Version: 0.1.3
# Summary: llama-index postprocessor flag embedding reranker integration
# Home-page:
# Author: Your Name
# Author-email: you@example.com
# License: MIT
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages
# Requires: llama-index-core
# Required-by:
# ---
# Name: llama-index-graph-stores-neo4j
# Version: 0.2.4
# Summary: llama-index graph stores neo4j integration
# Home-page:
# Author: Your Name
# Author-email: you@example.com
# License: MIT
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages
# Requires: llama-index-core, neo4j
# Required-by:
# ---
# Name: llama-parse
# Version: 0.4.4
# Summary: Parse files into RAG-Optimized formats.
# Home-page:
# Author: Logan Markewich
# Author-email: logan@llamaindex.ai
# License: MIT
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/notebooks/lib/python3.9/site-packages
# Requires: llama-index-core
# Required-by: llama-index-readers-llama-parse

# %%
sub_docs = []
sub_doc = Document(
                text="test chunck",
                metadata={},
            )
sub_docs.append(sub_doc)

# %%
index = PropertyGraphIndex.from_documents(
    sub_docs,
    embed_model=OpenAIEmbedding(model_name="text-embedding-3-small"),
    kg_extractors=[
        ImplicitPathExtractor(),
        SimpleLLMPathExtractor(
            llm=OpenAI(model="gpt-3.5-turbo", temperature=0.3),
            num_workers=4,
            max_paths_per_chunk=10,
        ),
    ],
    property_graph_store=graph_store,
    show_progress=True,
)
# Out:
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting implicit paths: 100%|██████████| 1/1 [00:00<00:00, 11915.64it/s]
# Extracting paths from text: 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.61it/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]

# %%
# run this if index is already loaded
index = PropertyGraphIndex.from_existing(
    graph_store,
    embed_model=OpenAIEmbedding(model_name="text-embedding-3-small"),
    kg_extractors=[
        ImplicitPathExtractor(),
        SimpleLLMPathExtractor(
            llm=OpenAI(model="gpt-3.5-turbo", temperature=0.3),
            num_workers=4,
            max_paths_per_chunk=10,
        ),
    ],
    show_progress=True,
)
# Out:
# Extracting implicit paths: 0it [00:00, ?it/s]
# Extracting paths from text: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]

# %% [markdown]
# The constructed knowledge graph should look something like this
# ![knowledge graph](./sf2023_budget_kg_screenshot.png)

# %% [markdown]
# #### Define Vector Retriever
#
# Here we define our vector context retriever - it returns initial nodes via vector search, and traverses the relations to pull in more nodes/context.

# %%
from llama_index.core.indices.property_graph import VectorContextRetriever

kg_retriever = VectorContextRetriever(
    index.property_graph_store,
    embed_model=OpenAIEmbedding(model_name="text-embedding-3-small"),
    similarity_top_k=2,
    path_depth=1,
    # include_text=False,
    include_text=True,
)

# %%
nodes = kg_retriever.retrieve(
    "Give me all the programs that the mayor's budget includes"
)
# nodes = kg_retriever.retrieve('san francisco')
print(len(nodes))
for idx, node in enumerate(nodes):
    print(f">> IDX: {idx}, {node.get_content()}")
# Out:
# 3
# >> IDX: 0, Here are some facts extracted from the provided text:
#
# Mayor's budget -> Includes -> Key changes
#
# first responders to petition for an individual to enter
# the programs. In these procedures, a CARE Plan is
# established, and a judge can use court orders with
# support such as short-term stabilization medications
# and beds, as well as wellness and recovery offerings.
# The Mayor’s proposed budget includes funding
# for engagement and assessment staff, new City
# attorneys dedicated to CARE Court implementation,
# increased capacity for treatment and housing, and
# outreach and educational efforts.
# Improvements at Laguna Honda Hospital
# Beyond behavioral health, this budget makes
# investments in DPH’s budget for Laguna Honda
# Hospital, which is actively working towards gaining
# recertification with the Centers for Medicare
# and Medicaid Services (CMS). DPH is currently
# implementing the action plan submitted to CMS,
# and it represents a significant facility-wide effort
# and includes hundreds of process improvements.
# The Mayor’s proposed budget includes over $3.5
# million of new annual investment to support the
# implementation of the action plan and sustain
# the improvements, including staffing in key areas,
# including education and training, patient care
# experience, medication management, and leadership
# within the San Francisco Health Network.
#
# Economic Recovery
# The Mayor’s proposed FY 2023-24 and FY 2024-
# 25 budget invests $24.4 million over the two years
# in support of the Roadmap for Downtown San
# Francisco’s Future, and broadly supports economic
# recovery across the entire City. While critical
# components around recovery include investments
# in public safety and street conditions, there are also
# targeted improvements and programs to support a
# thriving economy, both downtown and throughout
# the City’s neighborhood commercial corridors.
# Providing Tax Relief and Incentives
# To keep existing businesses stable and to recruit new
# businesses, the Mayor’s budget includes key changes
# to the City’s business taxes. In November 2020, San
# 20
#     20 EXECUTIVE SUMMARY
#                         EXECUTIVE SUMMARY
#
#
# Francisco voters passed Proposition F, which phased
# out the payroll expense tax, while gradually increasing
# gross receipts tax for businesses across most
# industries. The proposition also delayed gross receipts
# tax increases until 2023 and 2024 for industries hit
# hardest by the pandemic. In March 2023, the Mayor
# introduced legislation to further delay tax increases
# for maintenance and laundry businesses, retail trade,
# food services, manufacturing, accommodations, arts,
# entertainment, and recreation until 2025 and 2026.
# The proposed budget includes revenue assumptions
# aligned with these tax changes.
# The City must also attract new businesses to fill its
# office vacancies, support customer-serving businesses,
# and bolster future revenue through gross receipts
# tax, property tax, and contributions to other revenue
# sources. The Mayor’s legislation will offer a discount
# for up to three years on the office-based gross
# receipts tax for new offices locating in San Francisco
# in the information, administrative and support
# services, financial services, insurance, professional
# scientific and technical services industries.
#
# Finally, the budget proposes a change to the
# Commercial Rent Tax, which was passed by voters in
# June 2018. The change seeks to pause the collection
# revenues on sub-leases of commercial spaces through
# 2029 to ensure commercial properties are only
# subject to a single commercial rent tax, rather than
# also being taxed for sub-leasing the space. Profits on
# subleases will continue to be collected.
# Supporting Small Businesses
# The Mayor’s proposed budget continues the small
# business grant program, providing $5 million in direct
# grants to help small businesses across the city to
# stabilize, scale, and adapt business models to changed
# conditions. The program will target businesses in
# commercial corridors that have experienced the
# highest drop in sales tax to fill vacancies, or expand
# into new storefronts, while providing business
# assistance to improve operations and renegotiate
# leases
# >> IDX: 1, Here are some facts extracted from the provided text:
#
# Mayor's proposed budget -> Expands investments within -> San francisco police department
# Mayor's proposed budget -> Includes -> Funding
# Mayor's proposed budget -> Invests in -> Facilities maintenance
# Mayor's proposed budget -> Includes -> $32.0 million
# Mayor's proposed budget -> Includes -> Mental health services act funds
# Mayor's proposed budget -> Invests -> $24.4 million
# Mayor's proposed budget -> Invests in -> Stationary engineers
# Mayor's proposed budget -> Includes -> $17.7 million
# Mayor's proposed budget -> Leverages -> Ocoh
# Mayor's proposed budget -> Makes investments to -> Two positions
# Mayor's proposed budget -> Makes investments in -> Priority areas
# Mayor's proposed budget -> Continues -> Work
# Mayor's proposed budget -> Includes -> $1.2 million of grant funding
# Mayor's proposed budget -> Maintain -> Programs
# Mayor's proposed budget -> Includes -> $0.7 million
# Mayor's proposed budget -> Includes -> New funding to support efforts
# Mayor's proposed budget -> Includes -> Resources
# Mayor's proposed budget -> Makes investments to -> Continue supporting
# Mayor's proposed budget -> Includes -> Anticipated grant
# Mayor's proposed budget -> Invest in -> Expansion of recovery programs
# Mayor's proposed budget -> Includes -> $0.6 million
# Mayor's proposed budget -> Invests in -> Building projects
#
# CalAIM Expansion for People At-Risk of
# Institutionalization and Justice-Involved
# People
# The State of California is continuing its multi-year
# roll out of California Advancing and Innovating
# Medi-Cal (CalAIM), a new framework that
# encompasses a broad-based delivery system,
# program, and payment reform across the Medi-Cal
# program with a whole-person care approach. For
# the proposed FY 2023-24 and FY 2024-25 budget,
# the focus is on the roll-out of expanded benefits
# to people at risk of long-term institutionalization
# and justice-system involved people exiting jail.
# As CalAIM focuses on stabilizing patients in
# community settings as much as possible, the
# enhanced care management (ECM) benefit allows
# for Medi-Cal to pay for hands-on support to
# address both the clinical and non-clinical needs of
# medically complex patients to keep them out of
# institutions.
#
# Health Equity Investments through the
# Mental Health Services Act
# The Mayor’s proposed budget includes $32.0
# million in FY 2022-23 and $17.7 million of ongoing
#
#
# in additional Mental Health Services Act (MHSA)
# funds. These funds will be used to ensure the
# continuity of existing MHSA programming; support
# new, innovative and culturally congruent services
# to meet the pressing needs of the Black/African
# American community and sustain a pilot effort to
# provide mental health support for Black mothers.
# New initiatives in this budget include $15.0 million
# for a three-year pilot from FY 2023-24 through FY
# 2025-26 with the Dream Keeper Initiative to create
# a talk therapy, telehealth program for people in San
# Francisco, with a particular focus on Black/African
# American residents.
# Fee for Service Transition
#
# In January 2023, the San Francisco Health PlanNumber of Calls(SFHP) and Zuckerberg San Francisco General
#
# Hospital (ZSFG) expanded its use of the fee-for-
# service model to maximize revenues. By expanding
# the use of fee-for-service, ZSFG will recover
# more funding from the SFHP and the State, while
# maintaining quality care for its patients. DPH
# projects $36.7 M in additional revenues in FY 2023-
# 24 and $36.9 M in FY 2024-25 as result of the shift
# that is included in the Mayor’s proposed budget.
#
#
#
#
#                                                                                                           3,000
#
#
#                                           STREET RESPONSE TEAM. The goals                                 2,500
#                                              of the San Francisco Street Overdose
#                                         Response Team (SORT) are to reduce the                            2,000
#                                        risk of opioid-related death of individuals
#                                                   who have recently experienced an                         1,500
#                                     overdose, contribute to an overall reduction
#                                         in overdose deaths through referrals and
#                                        care coordination with community-based                              1,000
#                                          organziations, and to provide support to
#                                          people who have survived any overdose.                             500
#
#
#                                                                                                               0   Calls Handled  Calls Including Calls That Include  Clients Who
#                                                                                                                      by SORT      an Overdose  Buprennorphrine StartsAccepted Harm
#                                                                                                                                                                   Reduction Supplies
#                                                                                                                                        Types of Calls
#
#
#                                                                                                                                                PUBLIC HEALTH                       267
# >> IDX: 2, Here are some facts extracted from the provided text:
#
# Input -> Carefully considered in formulating -> Mayor's proposed budget
#
# Key Participants
# •  Residents provide direction for and commentary
#    on budget priorities throughout the annual budget
#    process. Input from residents through virtual
#    feedback forms, stakeholder working groups
#    convened by the Mayor’s Office, public budget
#    hearings, and communication with elected officials
#    are all carefully considered in formulating the
#    Mayor’s proposed budget.
# •  City departments prioritize needs and present
#    balanced budgets for review and analysis by the
#    Mayor’s Office of Public Policy and Finance.
# •  The multi-year budget projections described in the
#    previous section as well as the Capital Planning
#    Committee (CPC) and Committee on Information
#    Technology (COIT) provide guidance to the Mayor’s
#    Office on both long-term fiscal trends as well as
#    citywide priorities for capital and IT investments.
# •  The Mayor, with the assistance of the Mayor’s
#    Office of Public Policy and Finance, prepares
#    and submits a balanced budget to the Board of
#    Supervisors on an annual basis.
# •  The Board of Supervisors is the City’s legislative
#    body and is responsible for amending and
#    approving the Mayor’s proposed budget. The
#    Board’s Budget and Legislative Analyst also
#    participates in reviews of city spending and
#    financial projections and makes recommendations
#    to the Board on budget modifications.
# •  The Controller is the City’s Chief Financial Officer
#    and is responsible for projecting available revenue
#    to fund city operations and investments in both
#    the near- and long-term. In addition, the City
#    Services Auditor Division of the Controller’s Office
#    is responsible for working with departments to
#    develop, improve, and evaluate their performance
#    standards.
#
# Calendar and Process
# Beginning in September and concluding in July, the
# annual budget cycle can be divided into three major
# stages (see calendar at the end of this section):
#
# 50     BUDGET PROCESS
#
#
#
# •  Budget Preparation: budget development and
#    submission to the Board of Supervisors.
# •  Approval: budget review and enactment by the
#    Board of Supervisors and budget signing by the
#    Mayor
# •  Implementation: department execution and budget
#    adjustments.
#
# Budget Preparation
# Preliminary projections of Enterprise and General Fund
# revenues for the next fiscal year by the Controller’s
# Office and Mayor’s Office staff begin in September.
# Around this time, many departments begin budget
# planning to allow adequate input from oversight
# commissions and the public. In December, budget
# instructions are issued by the Mayor’s Office and
# the Controller’s Office with detailed guidance on the
# preparation of department budget requests. The
# instructions contain a financial outlook, policy goals,
# and guidelines as well as technical instructions.
# Three categories of budgets are prepared:
# •  General Fund department budgets: General Fund
#    departments rely in whole or in part on discretionary
#    revenue comprised primarily of local taxes such as
#    property, sales, payroll, and other taxes. The Mayor
#    introduces the proposed General Fund budget to
#    the Board of Supervisors on June 1.
#
# •  Enterprise department budgets: Enterprise
#    departments generate non-discretionary revenue
#    primarily from charges for services that are used
#    to support operations. The Mayor introduces
#    the proposed Enterprise budgets to the Board of
#    Supervisors on May 1.
# •  Capital and IT budgets: Capital and IT budget
#    requests are submitted to the CPC and COIT
#    for review. The recommendations for each
#    committee are taken into account during the budget
#    preparation process. The City’s Ten-Year Capital
#    Plan is brought before the Board of Supervisors and
#    Mayor for approval concurrently with the General
#    Fund and Enterprise department budgets.

# %% [markdown]
# ## Build Baseline Vector Index
#
# We also build a "baseline" vector index. This follows the "naive" RAG pipeline approach of chunking and vector embedding. We use this as a comparison point.

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine

base_index = VectorStoreIndex.from_documents(sub_docs, embed_model=embed_model)
base_retriever = base_index.as_retriever(similarity_top_k=2)
base_query_engine = RetrieverQueryEngine(base_retriever)

# %%
response = base_query_engine.query(
    "Give me all the programs that the mayor's budget includes"
)
print(str(response))
# Out:
# The mayor's budget includes the following programs:
#
# 1. Ongoing programmatic support for all districts.
# 2. One-time $5.0 million and $250,000 ongoing investment in priority community-based organization needs, including capital and infrastructure, and public safety.
# 3. Support for the Mayor’s Office Administration, which advances Mayoral priorities through policy and budget development, communications, and advocacy.
# 4. Financial Capability Services.
# 5. Nonprofit Capacity Building.
# 6. Eviction Prevention and Housing Stabilization Services.
# 7. Community and Housing Place-Based Services.
# 8. Civil Legal Services.
# 9. Supportive Housing for Persons with HIV/AIDS.
# 10. Community, Coalition, and Cultural District Building.
# 11. Rental and Homeownership Counseling.
# 12. Capital Projects.
# 13. Housing Development Grants.
# 14. Creation of permanently affordable housing.
# 15. Foster healthy communities and neighborhoods.
# 16. Improve access to affordable housing.
# 17. Preserve affordable housing.
# 18. Promote self-sufficiency and protect rights.
# 19. Investments in capital and information technology, including urgent repairs and crucial projects across the park system and ADA needs.
# 20. Replacement of critical City systems like the Computer Aided Dispatch system and the Property Tax System.
# 21. Funding for the Sheriff’s Jail Management System, JUSTIS Data Center of Excellence, Infrastructure Modernization, and digital accessibility.
# 22. New projects like the replacement of the legacy Legislative Management System and a new platform for the Empty Homes Tax.
# 23. Overdose prevention, treatment, and outreach programs funded by settlements with opioid manufacturers and distributors.
# 24. Savings targets in FY 2024-25 by reducing budgets for real estate expenses, software and technology licenses, and materials and supplies.
# 25. Lower-than-planned investments in citywide equipment, IT, and capital spending.
# 26. Use of reserves to help balance the budget while maintaining the bulk of the City’s reserves.

# %%
print(len(response.source_nodes))
for node in response.source_nodes:
    print("---")
    print(node.get_content())

# %% [markdown]
# ## Build Custom Retriever
#
# Build joint retriever that combines vector and KG search.

# %%
from llama_index.core.retrievers import BaseRetriever
from llama_index.core.schema import NodeWithScore
from typing import List


class CustomRetriever(BaseRetriever):
    """Custom retriever that performs both KG vector search and direct vector search."""

    def __init__(self, kg_retriever, vector_retriever):
        self._kg_retriever = kg_retriever
        self._vector_retriever = vector_retriever

    def _retrieve(self, query_bundle) -> List[NodeWithScore]:
        """Retrieve nodes given query."""
        kg_nodes = self._kg_retriever.retrieve(query_bundle)
        vector_nodes = self._vector_retriever.retrieve(query_bundle)

        unique_nodes = {n.node_id: n for n in kg_nodes}
        unique_nodes.update({n.node_id: n for n in vector_nodes})
        return list(unique_nodes.values())

# %%
custom_retriever = CustomRetriever(kg_retriever, base_retriever)

# %%
nodes = custom_retriever.retrieve(
    "Give me all the programs that the mayor's budget includes"
)
# len(nodes)

# %% [markdown]
# ## Build Agent
#
# Now that we have the retriever, we can treat it as a RAG pipeline tool, and wrap it with an agent that can perform basic CoT reasoning and maintain conversation memory over time.

# %%
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import RetrieverQueryEngine

kg_query_engine = RetrieverQueryEngine(custom_retriever)
kg_query_tool = QueryEngineTool(
    query_engine=kg_query_engine,
    metadata=ToolMetadata(
        name="query_tool",
        description="Provides information about the 2023 SF Budget Report.",
    ),
)

# %%
from llama_index.core.agent import FunctionCallingAgentWorker

agent_worker = FunctionCallingAgentWorker.from_tools(
    [kg_query_tool],
    llm=llm,
    verbose=True,
    allow_parallel_tool_calls=False,
)
agent = agent_worker.as_agent()

# %% [markdown]
# ## Try out Queries
#
# Now that the agent is setup, let's try out some queries.

# %%
response = agent.chat("Give me all the programs that the mayor's budget includes")
# Out:
# Added user message to memory: Give me all the programs that the mayor's budget includes
# === Calling Function ===
# Calling function: query_tool with args: {"input": "all programs included in the mayor's budget"}
# === Function Output ===
# The mayor's budget includes a variety of programs and investments:
#
# 1. **CARE Court Implementation**: Funding for engagement and assessment staff, new City attorneys, increased capacity for treatment and housing, and outreach and educational efforts.
# 2. **Laguna Honda Hospital**: Over $3.5 million for staffing in key areas, including education and training, patient care experience, medication management, and leadership.
# 3. **Economic Recovery**: $24.4 million over two years for the Roadmap for Downtown San Francisco’s Future and economic recovery across the city.
# 4. **Tax Relief and Incentives**: Changes to business taxes, including delaying tax increases for certain industries and offering discounts on office-based gross receipts tax for new offices.
# 5. **Small Business Support**: $5 million in direct grants to help small businesses stabilize, scale, and adapt.
# 6. **CalAIM Expansion**: Focus on expanded benefits for people at risk of long-term institutionalization and justice-system involved individuals.
# 7. **Mental Health Services Act**: $32.0 million in FY 2022-23 and $17.7 million ongoing for mental health services, including a $15.0 million pilot for a talk therapy telehealth program.
# 8. **Fee for Service Transition**: Expansion of the fee-for-service model to maximize revenues.
# 9. **Street Overdose Response Team (SORT)**: Efforts to reduce opioid-related deaths and provide support to overdose survivors.
# 10. **Capital and IT Investments**: $118 million over two years for urgent repairs and $53.9 million for vital technology projects.
# 11. **Dream Keeper Initiative**: Continued investment in San Francisco’s Black communities, including support for small businesses, housing programs, and health services.
# 12. **Climate Action Plan**: $2 million over two years to support staff at the Department of Environment.
# 13. **Good Government Initiatives**: Funding for hiring and contracting reforms, ongoing and new IT projects, and capital maintenance and critical repairs.
# 14. **Minimum Compensation Ordinance (MCO)**: Investments to increase wages for the lowest-paid workers providing City services.
#
# These programs reflect a broad range of priorities, including health, economic recovery, small business support, mental health services, and infrastructure improvements.
# === LLM Response ===
# The mayor's budget includes a comprehensive array of programs and investments, covering various sectors and priorities:
#
# 1. **CARE Court Implementation**: Funding for engagement and assessment staff, new City attorneys, increased capacity for treatment and housing, and outreach and educational efforts.
# 2. **Laguna Honda Hospital**: Over $3.5 million for staffing in key areas, including education and training, patient care experience, medication management, and leadership.
# 3. **Economic Recovery**: $24.4 million over two years for the Roadmap for Downtown San Francisco’s Future and economic recovery across the city.
# 4. **Tax Relief and Incentives**: Changes to business taxes, including delaying tax increases for certain industries and offering discounts on office-based gross receipts tax for new offices.
# 5. **Small Business Support**: $5 million in direct grants to help small businesses stabilize, scale, and adapt.
# 6. **CalAIM Expansion**: Focus on expanded benefits for people at risk of long-term institutionalization and justice-system involved individuals.
# 7. **Mental Health Services Act**: $32.0 million in FY 2022-23 and $17.7 million ongoing for mental health services, including a $15.0 million pilot for a talk therapy telehealth program.
# 8. **Fee for Service Transition**: Expansion of the fee-for-service model to maximize revenues.
# 9. **Street Overdose Response Team (SORT)**: Efforts to reduce opioid-related deaths and provide support to overdose survivors.
# 10. **Capital and IT Investments**: $118 million over two years for urgent repairs and $53.9 million for vital technology projects.
# 11. **Dream Keeper Initiative**: Continued investment in San Francisco’s Black communities, including support for small businesses, housing programs, and health services.
# 12. **Climate Action Plan**: $2 million over two years to support staff at the Department of Environment.
# 13. **Good Government Initiatives**: Funding for hiring and contracting reforms, ongoing and new IT projects, and capital maintenance and critical repairs.
# 14. **Minimum Compensation Ordinance (MCO)**: Investments to increase wages for the lowest-paid workers providing City services.
#
# These programs reflect a broad range of priorities, including health, economic recovery, small business support, mental health services, and infrastructure improvements.

# %%
print(str(response))
# Out:
# The mayor's budget includes a comprehensive array of programs and investments, covering various sectors and priorities:
#
# 1. **CARE Court Implementation**: Funding for engagement and assessment staff, new City attorneys, increased capacity for treatment and housing, and outreach and educational efforts.
# 2. **Laguna Honda Hospital**: Over $3.5 million for staffing in key areas, including education and training, patient care experience, medication management, and leadership.
# 3. **Economic Recovery**: $24.4 million over two years for the Roadmap for Downtown San Francisco’s Future and economic recovery across the city.
# 4. **Tax Relief and Incentives**: Changes to business taxes, including delaying tax increases for certain industries and offering discounts on office-based gross receipts tax for new offices.
# 5. **Small Business Support**: $5 million in direct grants to help small businesses stabilize, scale, and adapt.
# 6. **CalAIM Expansion**: Focus on expanded benefits for people at risk of long-term institutionalization and justice-system involved individuals.
# 7. **Mental Health Services Act**: $32.0 million in FY 2022-23 and $17.7 million ongoing for mental health services, including a $15.0 million pilot for a talk therapy telehealth program.
# 8. **Fee for Service Transition**: Expansion of the fee-for-service model to maximize revenues.
# 9. **Street Overdose Response Team (SORT)**: Efforts to reduce opioid-related deaths and provide support to overdose survivors.
# 10. **Capital and IT Investments**: $118 million over two years for urgent repairs and $53.9 million for vital technology projects.
# 11. **Dream Keeper Initiative**: Continued investment in San Francisco’s Black communities, including support for small businesses, housing programs, and health services.
# 12. **Climate Action Plan**: $2 million over two years to support staff at the Department of Environment.
# 13. **Good Government Initiatives**: Funding for hiring and contracting reforms, ongoing and new IT projects, and capital maintenance and critical repairs.
# 14. **Minimum Compensation Ordinance (MCO)**: Investments to increase wages for the lowest-paid workers providing City services.
#
# These programs reflect a broad range of priorities, including health, economic recovery, small business support, mental health services, and infrastructure improvements.

# %%
agent.reset()
response = agent.chat(
    "Compare the budget for DPA Police Accountabilty from 2022-2023 to 2023-2024"
)
print(str(response))
# Out:
# Added user message to memory: Compare the budget for DPA Police Accountabilty from 2022-2023 to 2023-2024
# === Calling Function ===
# Calling function: query_tool with args: {"input": "DPA Police Accountability budget for 2022-2023"}
# === Function Output ===
# The DPA Police Accountability budget for 2022-2023 is $9,776,177.
# === Calling Function ===
# Calling function: query_tool with args: {"input": "DPA Police Accountability budget for 2023-2024"}
# === Function Output ===
# The budget for the Department of Police Accountability for the fiscal year 2023-2024 is $9,990,353.
# === LLM Response ===
# The budget for the Department of Police Accountability (DPA) has increased from $9,776,177 in the fiscal year 2022-2023 to $9,990,353 in the fiscal year 2023-2024. This represents an increase of $214,176.
# The budget for the Department of Police Accountability (DPA) has increased from $9,776,177 in the fiscal year 2022-2023 to $9,990,353 in the fiscal year 2023-2024. This represents an increase of $214,176.

# %%
print(str(response.source_nodes[0].get_content()))
# Out:
# Here are some facts extracted from the provided text:
#
# Dpa department of police accountability -> Has -> Total funded positions
#
# ORGANIZATIONAL STRUCTURE: POLICE ACCOUNTABILITY
#
#
#                                                                        Executive Director
#
#
#                                    Chief of Staff                                                                           Chief of Investigations
#
#
#           Audit                     Operations                       Legal                                        Investigations                  Mediation
#
#
#                                                        Policy                     SB 1421
#
#
# Department Total Budget Historical Comparison (Mayor's Proposed)                                                                      Budget Year 2023-2024 and 2024-2025
#
#
#                                            Department Total Budget Historical Comparison
#  DPA Department Of Police AccountabilityTOTAL BUDGET – HISTORICAL COMPARISON2022-2023      2023-2024              CHANGE             2024-2025          CHANGE
#      FUNDED POSITIONS                                                  ORIGINAL            PROPOSED                 FROM             PROPOSED             FROM
#                                                                      2022-2023BUDGET       2023-2024BUDGETChanges from2022-2023      2024-2025BUDGETChanges from2023-2024
# Funded Positions                                               Original Budget     Proposed Budget             2022-2023     Proposed Budget              2023-2024
#   Total Funded                                                            45.17                 41.95               (3.22)                41.85               (0.10)
#   Non-Operating Positions (CAP/Other)                                     (2.00)                (1.00)                1.00                (1.00)
#   Net Operating Positions                                                 43.17                 40.95               (2.22)                40.85               (0.10)
#
#
# Sources
#   Expenditure Recovery                                                 128,000               332,795              204,795               332,795
#
#
#   General Fund                                                       9,648,177             9,657,558                9,381             9,488,396           (169,162)
#   Sources Total                                                      9,776,177             9,990,353              214,176             9,821,191           (169,162)
#
#
# Uses - Operating Expenditures
#   Salaries                                                           6,003,750             5,930,159              (73,591)            6,158,974             228,815
#   Mandatory Fringe Benefits                                          2,257,157             2,086,784            (170,373)             2,143,678              56,894
#   Non-Personnel Services                                               324,336               334,336               10,000               333,742                (594)
#   Materials & Supplies                                                   34,918                34,918                                    31,426              (3,492)
#   Programmatic Projects                                                100,000               500,000              400,000               100,000           (400,000)
#   Services Of Other Depts                                            1,056,016             1,104,156               48,140             1,053,371             (50,785)
#   Uses Total                                                         9,776,177             9,990,353              214,176             9,821,191           (169,162)
#
#
# Uses - By Division Description
#   DPA Police Accountabilty                                           9,776,177             9,990,353              214,176             9,821,191           (169,162)
#   Uses by Division Total                                             9,776,177             9,990,353              214,176             9,821,191           (169,162)
#
#
#                                                                                                         POLICE ACCOUNTABILITY                              249
